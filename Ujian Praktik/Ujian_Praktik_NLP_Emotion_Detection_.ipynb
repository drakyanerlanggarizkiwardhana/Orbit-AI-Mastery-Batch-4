# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/indonesian-twitter-emotion/Twitter_Emotion_Dataset.csv
# /kaggle/input/indonesian-twitter-emotion/kamus_singkatan.csv

# %% [markdown]
# Mengimport numpy dan pandas library, dan kemudian menunjukkan cara membaca file dari direktori input di Kaggle

# %%
from collections import Counter
import nltk
import re
import string

# %% [markdown]
# Mengimport modul-modul Python yang berguna untuk melakukan pemrosesan teks dan analisis bahasa natural.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from wordcloud import WordCloud, STOPWORDS
from nltk.corpus import stopwords

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv("../input/indonesian-twitter-emotion/Twitter_Emotion_Dataset.csv")

# %%
df
# Out:
#         label                                              tweet
# 0       anger  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1       anger  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2       happy  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3       anger  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4       happy  Sharing pengalaman aja, kemarin jam 18.00 bata...
# ...       ...                                                ...
# 4396     love  Tahukah kamu, bahwa saat itu papa memejamkan m...
# 4397     fear  Sulitnya menetapkan Calon Wapresnya Jokowi di ...
# 4398    anger  5. masa depannya nggak jelas. lha iya, gimana ...
# 4399    happy  [USERNAME] dulu beneran ada mahasiswa Teknik U...
# 4400  sadness  Ya Allah, hanya Engkau yang mengetahui rasa sa...
#
# [4401 rows x 2 columns]

# %% [markdown]
# #EDA

# %%
df.columns
# Out:
# Index(['label', 'tweet'], dtype='object')

# %%
df.shape
# Out:
# (4401, 2)

# %%
#no nuls value
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    label                                              tweet
# 0  anger  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1  anger  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2  happy  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3  anger  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4  happy  Sharing pengalaman aja, kemarin jam 18.00 bata...

# %%
temp = df.groupby('label').count()['tweet'].reset_index().sort_values(by='tweet', ascending=False)
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_475f4_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_475f4_row1_col1 {
#   background-color: #5e3a98;
#   color: #f1f1f1;
# }
# #T_475f4_row2_col1 {
#   background-color: #65489f;
#   color: #f1f1f1;
# }
# #T_475f4_row3_col1 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_475f4_row4_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_475f4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >label</th>
#       <th class="col_heading level0 col1" >tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_475f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_475f4_row0_col0" class="data row0 col0" >anger</td>
#       <td id="T_475f4_row0_col1" class="data row0 col1" >1101</td>
#     </tr>
#     <tr>
#       <th id="T_475f4_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_475f4_row1_col0" class="data row1 col0" >happy</td>
#       <td id="T_475f4_row1_col1" class="data row1 col1" >1017</td>
#     </tr>
#     <tr>
#       <th id="T_475f4_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_475f4_row2_col0" class="data row2 col0" >sadness</td>
#       <td id="T_475f4_row2_col1" class="data row2 col1" >997</td>
#     </tr>
#     <tr>
#       <th id="T_475f4_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_475f4_row3_col0" class="data row3 col0" >fear</td>
#       <td id="T_475f4_row3_col1" class="data row3 col1" >649</td>
#     </tr>
#     <tr>
#       <th id="T_475f4_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_475f4_row4_col0" class="data row4 col0" >love</td>
#       <td id="T_475f4_row4_col1" class="data row4 col1" >637</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Kode di atas mengelompokkan tweet berdasarkan label emosi yang terdapat pada dataframe df, kemudian menghitung jumlah tweet pada setiap kelompok dan menyimpannya dalam kolom tweet. Selanjutnya, hasil pengelompokan dan penghitungan tersebut diurutkan berdasarkan jumlah tweet secara menurun.
#
# Kemudian, temp.style.background_gradient(cmap='Purples') digunakan untuk memberikan warna latar belakang pada hasil pengurutan tersebut, dengan skala warna yang diberikan adalah "Purples". Warna latar belakang yang lebih gelap menunjukkan nilai yang lebih tinggi. Hasil tersebut ditampilkan dalam bentuk tabel.

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='label', data=df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# Kode di atas digunakan untuk membuat visualisasi grafik dengan menggunakan library seaborn. Lebih tepatnya, kode tersebut digunakan untuk membuat sebuah bar plot yang menunjukkan jumlah tweet pada setiap label emosi yang terdapat pada dataframe df.
#
# plt.figure(figsize=(12,6)) digunakan untuk menentukan ukuran dari grafik yang akan dibuat.
#
# sns.countplot(x='label', data=df) digunakan untuk membuat bar plot dengan sumbu x diisi dengan kolom 'label' pada dataframe df. Nilai pada sumbu y akan menunjukkan jumlah tweet pada setiap label emosi.

# %%
fig=go.Figure(go.Funnelarea(
    text=temp.label,
    values=temp.tweet,
    title= {"position":"top center", "text": "Funnel-chart on Case Number Distribution"}))
fig.show()
# Out:
# <div>                            <div id="69e82df3-d735-42f6-98ac-73e4fcf8ee39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69e82df3-d735-42f6-98ac-73e4fcf8ee39")) {                    Plotly.newPlot(                        "69e82df3-d735-42f6-98ac-73e4fcf8ee39",                        [{"text":["anger","happy","sadness","fear","love"],"title":{"position":"top center","text":"Funnel-chart on Case Number Distribution"},"values":[1101,1017,997,649,637],"type":"funnelarea"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}} ...
#
# var gd = document.getElementById('69e82df3-d735-42f6-98ac-73e4fcf8ee39');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none

# %% [markdown]
# Membuat funnel chart atau diagram funnel yang menunjukkan distribusi jumlah kasus pada setiap label emosi pada dataset yang diberikan. Pada kode tersebut, terlebih dahulu dilakukan penghitungan jumlah tweet pada setiap label dengan menggunakan fungsi groupby dan count pada pandas dataframe. Kemudian, hasil penghitungan tersebut ditampilkan dalam bentuk diagram funnel menggunakan package plotly.graph_objects. Diagram funnel digunakan untuk memvisualisasikan data secara hierarkis, di mana setiap tingkat menunjukkan jumlah data yang semakin mengecil dari atas ke bawah. Pada kode tersebut, label emosi ditampilkan di bagian atas diagram, sedangkan tingkat di bawahnya menunjukkan jumlah tweet yang terkait dengan label tersebut.

# %% [markdown]
# **Most Common Word**

# %%
df['temp']= df['tweet'].apply(lambda x: str(x).split())
top= Counter([item for sublist in df['temp'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns=["Common_words", 'count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_fbb9e_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fbb9e_row1_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_fbb9e_row2_col1 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_fbb9e_row3_col1 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_fbb9e_row4_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_fbb9e_row5_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_fbb9e_row6_col1, #T_fbb9e_row7_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_fbb9e_row8_col1 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_fbb9e_row9_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_fbb9e_row10_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_fbb9e_row11_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_fbb9e_row12_col1 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_fbb9e_row13_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_fbb9e_row14_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_fbb9e_row15_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_fbb9e_row16_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_fbb9e_row17_col1, #T_fbb9e_row18_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_fbb9e_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_fbb9e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbb9e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fbb9e_row0_col0" class="data row0 col0" >[USERNAME]</td>
#       <td id="T_fbb9e_row0_col1" class="data row0 col1" >1754</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fbb9e_row1_col0" class="data row1 col0" >yg</td>
#       <td id="T_fbb9e_row1_col1" class="data row1 col1" >1607</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fbb9e_row2_col0" class="data row2 col0" >yang</td>
#       <td id="T_fbb9e_row2_col1" class="data row2 col1" >1572</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fbb9e_row3_col0" class="data row3 col0" >dan</td>
#       <td id="T_fbb9e_row3_col1" class="data row3 col1" >1527</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fbb9e_row4_col0" class="data row4 col0" >di</td>
#       <td id="T_fbb9e_row4_col1" class="data row4 col1" >1518</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fbb9e_row5_col0" class="data row5 col0" >aku</td>
#       <td id="T_fbb9e_row5_col1" class="data row5 col1" >894</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fbb9e_row6_col0" class="data row6 col0" >itu</td>
#       <td id="T_fbb9e_row6_col1" class="data row6 col1" >841</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fbb9e_row7_col0" class="data row7 col0" >ada</td>
#       <td id="T_fbb9e_row7_col1" class="data row7 col1" >840</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fbb9e_row8_col0" class="data row8 col0" >ini</td>
#       <td id="T_fbb9e_row8_col1" class="data row8 col1" >747</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fbb9e_row9_col0" class="data row9 col0" >sama</td>
#       <td id="T_fbb9e_row9_col1" class="data row9 col1" >692</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fbb9e_row10_col0" class="data row10 col0" >ga</td>
#       <td id="T_fbb9e_row10_col1" class="data row10 col1" >655</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fbb9e_row11_col0" class="data row11 col0" >[URL]</td>
#       <td id="T_fbb9e_row11_col1" class="data row11 col1" >620</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fbb9e_row12_col0" class="data row12 col0" >bisa</td>
#       <td id="T_fbb9e_row12_col1" class="data row12 col1" >608</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fbb9e_row13_col0" class="data row13 col0" >ke</td>
#       <td id="T_fbb9e_row13_col1" class="data row13 col1" >564</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fbb9e_row14_col0" class="data row14 col0" >kita</td>
#       <td id="T_fbb9e_row14_col1" class="data row14 col1" >526</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fbb9e_row15_col0" class="data row15 col0" >mau</td>
#       <td id="T_fbb9e_row15_col1" class="data row15 col1" >517</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fbb9e_row16_col0" class="data row16 col0" >dia</td>
#       <td id="T_fbb9e_row16_col1" class="data row16 col1" >498</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fbb9e_row17_col0" class="data row17 col0" >saya</td>
#       <td id="T_fbb9e_row17_col1" class="data row17 col1" >494</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fbb9e_row18_col0" class="data row18 col0" >aja</td>
#       <td id="T_fbb9e_row18_col1" class="data row18 col1" >493</td>
#     </tr>
#     <tr>
#       <th id="T_fbb9e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fbb9e_row19_col0" class="data row19 col0" >ya</td>
#       <td id="T_fbb9e_row19_col1" class="data row19 col1" >470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Membuat dataframe baru 'temp' yang berisi kata-kata yang paling umum muncul dalam tweet. Pertama, kolom 'temp' ditambahkan ke dataframe 'df' dengan menggunakan fungsi lambda untuk membagi setiap tweet menjadi daftar kata-kata. Kemudian, sebuah Counter dibuat untuk menghitung frekuensi setiap kata di dalam daftar tersebut. 20 kata yang paling sering muncul kemudian dipilih dan ditampilkan dalam bentuk dataframe baru 'temp' dengan dua kolom: 'Common_words' dan 'count'. Akhirnya, background gradient dari dataframe 'temp' diatur agar berwarna biru (cmap='Blues').

# %%
fig = px.treemap(temp, path=['Common_words'], values='count', title='Tree of Most Common words')
fig.show()
# Out:
# <div>                            <div id="166de97b-e65b-49cb-b140-6c8f5e85cefe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("166de97b-e65b-49cb-b140-6c8f5e85cefe")) {                    Plotly.newPlot(                        "166de97b-e65b-49cb-b140-6c8f5e85cefe",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["[URL]","[USERNAME]","ada","aja","aku","bisa","dan","di","dia","ga","ini","itu","ke","kita","mau","sama","saya","ya","yang","yg"],"labels":["[URL]","[USERNAME]","ada","aja","aku","bisa","dan","di","dia","ga","ini","itu","ke","kita","mau","sama","saya","ya","yang","yg"],"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":[620,1754,840,493,894,608,1527,1518,498,655,747,841,564,526,517,692,494,470,1572,1607],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth": ...

# %% [markdown]
# Membuat sebuah treemap yang menampilkan 20 kata yang paling umum muncul dalam tweet. Treemap adalah sebuah visualisasi hierarkis yang menampilkan data dalam bentuk kotak-kotak yang saling bersarang, dan ukuran kotak menunjukkan besarnya proporsi nilai pada data. Pada kasus ini, setiap kotak pada treemap menunjukkan sebuah kata yang muncul dalam tweet, dan ukuran kotak menunjukkan seberapa sering kata tersebut muncul. Semakin besar kotak, semakin sering kata tersebut muncul dalam tweet. Pada treemap ini, kata-kata yang paling sering muncul ditampilkan pada kotak yang lebih besar.

# %%
fig = px.bar(temp,x="count", y="Common_words", 
             title="Common words in Selected Text", orientation='h', width=700, height=700,color='Common_words')
fig.show()
# Out:
# <div>                            <div id="18462656-df5a-49f4-aa7e-5a64fe957138" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18462656-df5a-49f4-aa7e-5a64fe957138")) {                    Plotly.newPlot(                        "18462656-df5a-49f4-aa7e-5a64fe957138",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"[USERNAME]","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"[USERNAME]","offsetgroup":"[USERNAME]","orientation":"h","showlegend":true,"textposition":"auto","x":[1754],"xaxis":"x","y":["[USERNAME]"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"yg","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"yg","offsetgroup":"yg","orientation":"h","showlegend":true,"textposition":"auto","x":[1607],"xaxis":"x","y":["yg"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"yang","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"yang","offsetgroup":"yang","orientation":"h","showlegend":true,"textposition":"auto","x":[1572],"xaxis":"x","y":["yang"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"dan","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"dan","offsetgroup":"dan","orientation":"h","showlegend":true,"textposition":"auto","x":[1527],"xaxis":"x","y":["dan"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"di","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"di","offsetgroup":"di","orientation":"h","showlegend":true,"textposition":"auto","x":[1518],"xaxis":"x","y":["di"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"aku","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"aku","offsetgroup":"aku","orientation":"h","showlegend":true,"textposition":"auto","x":[894],"xaxis":"x","y":["aku"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"itu","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"itu","offsetgroup":"itu","orientation":"h","showlegend":true,"textposition":"auto","x":[841],"xaxis":"x","y":["itu"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"ada","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"ada","offsetgroup":"ada","orientation":"h","showlegend":true,"textposition":"auto","x":[840],"xaxis":"x","y":["ada"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"ini","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"ini","offsetgroup":"ini","orientation":"h","showlegend":true,"textposition":"auto","x":[747],"xaxis":"x","y":["ini"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"sama","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"sama","offsetgroup":"sama","orientation":"h","showlegend":true,"textposition":"auto","x":[692],"xaxis":"x","y":["sama"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"ga","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ga","offsetgroup":"ga","orientation":"h","showlegend":true,"textposition":"auto","x":[655],"xaxis":"x","y":["ga"],"yaxis":"y","type":"ba ...

# %% [markdown]
# Grafik bar di atas menampilkan 20 kata yang paling umum muncul pada tweet. Sumbu X menunjukkan jumlah kemunculan kata-kata tersebut, sementara sumbu Y menunjukkan kata-kata tersebut. Setiap batang berwarna-warni merepresentasikan masing-masing kata. Semakin tinggi batang, semakin sering kata tersebut muncul dalam tweet.

# %%
most_popular_case = df[df['label']=="anger"]

# %% [markdown]
# Melakukan filter data frame df dengan hanya mengambil baris-baris yang memiliki label "anger" pada kolom "label", dan menyimpannya ke dalam variabel most_popular_case.

# %%
#MosT common  words in 
top = Counter([item for sublist in most_popular_case['temp'] for item in sublist])
temp_positive = pd.DataFrame(top.most_common(20))
temp_positive.columns = ['Common_words','count']
temp_positive.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_03393_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_03393_row1_col1 {
#   background-color: #50b264;
#   color: #f1f1f1;
# }
# #T_03393_row2_col1 {
#   background-color: #97d492;
#   color: #000000;
# }
# #T_03393_row3_col1 {
#   background-color: #bde5b6;
#   color: #000000;
# }
# #T_03393_row4_col1 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_03393_row5_col1 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_03393_row6_col1 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_03393_row7_col1 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_03393_row8_col1 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_03393_row9_col1 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_03393_row10_col1 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_03393_row11_col1 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_03393_row12_col1, #T_03393_row13_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_03393_row14_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_03393_row15_col1, #T_03393_row16_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_03393_row17_col1, #T_03393_row18_col1, #T_03393_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_03393_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Common_words</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03393_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03393_row0_col0" class="data row0 col0" >[USERNAME]</td>
#       <td id="T_03393_row0_col1" class="data row0 col1" >832</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_03393_row1_col0" class="data row1 col0" >yg</td>
#       <td id="T_03393_row1_col1" class="data row1 col1" >543</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_03393_row2_col0" class="data row2 col0" >di</td>
#       <td id="T_03393_row2_col1" class="data row2 col1" >412</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_03393_row3_col0" class="data row3 col0" >dan</td>
#       <td id="T_03393_row3_col1" class="data row3 col1" >326</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_03393_row4_col0" class="data row4 col0" >yang</td>
#       <td id="T_03393_row4_col1" class="data row4 col1" >281</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_03393_row5_col0" class="data row5 col0" >ga</td>
#       <td id="T_03393_row5_col1" class="data row5 col1" >253</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_03393_row6_col0" class="data row6 col0" >itu</td>
#       <td id="T_03393_row6_col1" class="data row6 col1" >239</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_03393_row7_col0" class="data row7 col0" >ada</td>
#       <td id="T_03393_row7_col1" class="data row7 col1" >233</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_03393_row8_col0" class="data row8 col0" >mau</td>
#       <td id="T_03393_row8_col1" class="data row8 col1" >172</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_03393_row9_col0" class="data row9 col0" >ini</td>
#       <td id="T_03393_row9_col1" class="data row9 col1" >171</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_03393_row10_col0" class="data row10 col0" >[URL]</td>
#       <td id="T_03393_row10_col1" class="data row10 col1" >168</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_03393_row11_col0" class="data row11 col0" >aja</td>
#       <td id="T_03393_row11_col1" class="data row11 col1" >162</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_03393_row12_col0" class="data row12 col0" >sama</td>
#       <td id="T_03393_row12_col1" class="data row12 col1" >150</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_03393_row13_col0" class="data row13 col0" >saya</td>
#       <td id="T_03393_row13_col1" class="data row13 col1" >150</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_03393_row14_col0" class="data row14 col0" >ke</td>
#       <td id="T_03393_row14_col1" class="data row14 col1" >137</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_03393_row15_col0" class="data row15 col0" >orang</td>
#       <td id="T_03393_row15_col1" class="data row15 col1" >136</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_03393_row16_col0" class="data row16 col0" >gak</td>
#       <td id="T_03393_row16_col1" class="data row16 col1" >132</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_03393_row17_col0" class="data row17 col0" >bisa</td>
#       <td id="T_03393_row17_col1" class="data row17 col1" >129</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_03393_row18_col0" class="data row18 col0" >ya</td>
#       <td id="T_03393_row18_col1" class="data row18 col1" >129</td>
#     </tr>
#     <tr>
#       <th id="T_03393_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_03393_row19_col0" class="data row19 col0" >dia</td>
#       <td id="T_03393_row19_col1" class="data row19 col1" >128</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Mencari kata-kata yang paling umum (most common) dalam tweet yang dikategorikan sebagai "anger".

# %%
fig = px.bar(temp_positive, x="count", y="Common_words", title='Most Commmon Words popular cases Words', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <div>                            <div id="6193c965-ae6e-44f8-b234-a36f32b7b858" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6193c965-ae6e-44f8-b234-a36f32b7b858")) {                    Plotly.newPlot(                        "6193c965-ae6e-44f8-b234-a36f32b7b858",                        [{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"[USERNAME]","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"[USERNAME]","offsetgroup":"[USERNAME]","orientation":"h","showlegend":true,"textposition":"auto","x":[832],"xaxis":"x","y":["[USERNAME]"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"yg","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"yg","offsetgroup":"yg","orientation":"h","showlegend":true,"textposition":"auto","x":[543],"xaxis":"x","y":["yg"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"di","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"di","offsetgroup":"di","orientation":"h","showlegend":true,"textposition":"auto","x":[412],"xaxis":"x","y":["di"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"dan","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"dan","offsetgroup":"dan","orientation":"h","showlegend":true,"textposition":"auto","x":[326],"xaxis":"x","y":["dan"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"yang","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"yang","offsetgroup":"yang","orientation":"h","showlegend":true,"textposition":"auto","x":[281],"xaxis":"x","y":["yang"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"ga","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"ga","offsetgroup":"ga","orientation":"h","showlegend":true,"textposition":"auto","x":[253],"xaxis":"x","y":["ga"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"itu","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"itu","offsetgroup":"itu","orientation":"h","showlegend":true,"textposition":"auto","x":[239],"xaxis":"x","y":["itu"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"ada","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"ada","offsetgroup":"ada","orientation":"h","showlegend":true,"textposition":"auto","x":[233],"xaxis":"x","y":["ada"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"mau","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"mau","offsetgroup":"mau","orientation":"h","showlegend":true,"textposition":"auto","x":[172],"xaxis":"x","y":["mau"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"ini","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"ini","offsetgroup":"ini","orientation":"h","showlegend":true,"textposition":"auto","x":[171],"xaxis":"x","y":["ini"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Common_words=%{y}<br>count=%{x}<extra></extra>","legendgroup":"[URL]","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"[URL]","offsetgroup":"[URL]","orientation":"h","showlegend":true,"textposition":"auto","x":[168],"xaxis":"x","y":["[URL]"],"yaxis":"y","type":"bar ...

# %% [markdown]
# Grafik tersebut menunjukkan 20 kata yang paling umum digunakan dalam tweet yang termasuk dalam kategori kemarahan (anger). Setiap baris pada grafik menunjukkan kata yang paling umum digunakan dan jumlah kali kata tersebut muncul dalam tweet. Semakin tinggi bar, semakin banyak kata tersebut digunakan dalam tweet yang termasuk dalam kategori kemarahan. Grafik ini memberikan informasi tentang kata-kata yang paling sering digunakan dalam tweet yang termasuk dalam kategori kemarahan, yang dapat memberikan wawasan tentang topik atau isu yang memicu kemarahan pada orang-orang.

# %%
# if n_words=1 -> unigrams, if n_words=2 -> bigrams..
def get_top_Nwords(corpus, n=None, remove_stop_words=False, n_words=1):
    if remove_stop_words:
        vec = CountVectorizer(stop_words='english', ngram_range=(n_words, n_words)).fit(corpus)
    else:
        vec = CountVectorizer(ngram_range=(n_words, n_words)).fit(corpus)
    
    bag_ofWords =vec.transform(corpus)
    sum_words = bag_ofWords.sum(axis=0)
    words_freq = [(word, sum_words[0,idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:n]

# %% [markdown]
# Fungsi get_top_Nwords yang ada pada kode diatas digunakan untuk mengembalikan daftar kata-kata yang paling sering muncul dalam dokumen atau korpus. Jumlah kata-kata yang ingin ditampilkan dapat diatur dengan parameter n. Jika ingin menghilangkan stop words, set parameter remove_stop_words=True. Jika ingin mencari kata-kata yang terdiri dari dua kata (bigram), atur parameter n_words=2. Fungsi ini menggunakan CountVectorizer dari library sklearn untuk membuat representasi bag-of-words dari teks.

# %% [markdown]
# **Bigram Distribution**

# %%
common_words = get_top_Nwords(df['tweet'].drop_duplicates(), 20, remove_stop_words=True, n_words=2)
for word, freq in common_words:
    print(word, freq)
# Out:
# username username 634
# ada yang 91
# ada yg 87
# orang yang 86
# jatuh cinta 78
# hari ini 68
# username url 65
# orang lain 65
# orang yg 58
# terima kasih 58
# apa yang 55
# ga ada 53
# ya allah 53
# aku sayang 45
# ga bisa 43
# salah satu 42
# sayang banget 41
# orang orang 40
# ada di 36
# saat ini 36

# %% [markdown]
# Melakukan penghitungan kata-kata yang paling sering muncul pada dataset tweet yang ada.

# %%
train_temp =pd.DataFrame(common_words, columns=['text', 'count'])
fig = plt.figure(figsize=(10,8))
ax1 = train_temp.groupby('text').sum()['count'].sort_values(ascending=False).plot(kind='bar',
                                                                            color='#120f7b')
ax1.set_title("Bigram_distributin")
ax1.set_xlabel('Bigram')
ax1.set_ylabel("frequency")
plt.show()

# %% [markdown]
# Menunjukkan grafik batang untuk distribusi bigram dari data tweet yang diambil dari dataset.

# %%
common_words = get_top_Nwords(df['tweet'].drop_duplicates(), 20, remove_stop_words=True, n_words=3)
for word, freq in common_words:
    print(word, freq)
# Out:
# username username username 329
# username username url 27
# sayang banget sama 21
# aku cinta kamu 20
# selamat ulang tahun 16
# aku sayang kamu 15
# kamu aku cinta 15
# cinta kamu aku 15
# kepada allaah swt 13
# aku berlindung kepada 12
# berlindung kepada allaah 12
# tidak ada yang 11
# pada saat itu 11
# yang ada di 11
# stiap rmh sakit 11
# satu sama lain 10
# allaah swt dari 10
# swt dari godaan 10
# dari godaan setan 10
# godaan setan yang 10

# %% [markdown]
# **Trigram distribution**

# %%
train_temp =pd.DataFrame(common_words, columns=['text', 'count'])
fig = plt.figure(figsize=(10,8))
ax1 = train_temp.groupby('text').sum()['count'].sort_values(ascending=False).plot(kind='bar',
                                                                            color='#120f7b')
ax1.set_title("Tigram_distributin")
ax1.set_xlabel('Tigram')
ax1.set_ylabel("frequency")
plt.show()

# %%
stopwords=set(STOPWORDS)
wordclouds=WordCloud(width=800, 
                    height=700,
                    background_color='white',
                    max_font_size=120,
                    min_font_size=10,
                    stopwords=stopwords).generate(''.join(df['tweet']))

#plot the worldcloud image
plt.figure(figsize=(8,8), facecolor=None)
plt.imshow(wordclouds)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# #Preprocessing

# %%
df['tweet'] = " " + df['tweet'] + " "

# %%
import pandas as pd

# Membaca file CSV dan menyimpannya ke dalam dataframe
df = pd.read_csv("/kaggle/input/indonesian-twitter-emotion/Twitter_Emotion_Dataset.csv")

# Membersihkan tweet dari karakter-karakter yang tidak diperlukan
df['tweet'] = df['tweet'].str.replace(r"((\\x[a-z0-9]{1,}){1,})", "", regex=False)
df['tweet'] = df['tweet'].str.replace("USERNAME", "", regex=False)
df['tweet'] = df['tweet'].str.replace(r"http\S+", "", regex=False)
df['tweet'] = df['tweet'].str.replace("URL", "", regex=False)
df['tweet'] = df['tweet'].str.replace('@[^\s]+', "", regex=False)
df['tweet'] = df['tweet'].str.replace(r'#([^\s]+)', "", regex=False)
df['tweet'] = df['tweet'].str.replace(r"\\n", " ", regex=False)
df['tweet'] = df['tweet'].str.replace("SENSITIVE-NO", "", regex=False)
df['tweet'] = df['tweet'].str.replace("askmf", "", regex=False)

# Menampilkan lima baris pertama dari dataframe
print(df.head())
# Out:
#    label                                              tweet
# 0  anger  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1  anger  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2  happy  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3  anger  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4  happy  Sharing pengalaman aja, kemarin jam 18.00 bata...

# %%
#Menghapus tanda baca
df['tweet'] = df['tweet'].str.translate(str.maketrans(string.punctuation, ' '*len(string.punctuation)))
#Menghapus angka
df['tweet'] = df['tweet'].replace(regex='\d+', value='')
#lowercase
df['tweet'] = df['tweet'].str.lower()

# %% [markdown]
# #Feature Extraction

# %%
X = df['tweet']
y = df['label'].values

# %%
#text = df['processed']
count_vect = CountVectorizer()
X_count = count_vect.fit_transform(X)

tfidf_transformer = TfidfTransformer()
X_tfidf = tfidf_transformer.fit_transform(X_count)

# %% [markdown]
# #Building Model

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(multi_class='multinomial', penalty='l2', solver='newton-cg', C= 1.623776739188721)
classifier.fit(X_tfidf, y)
# Out:
# LogisticRegression(C=1.623776739188721, multi_class='multinomial',
#                    solver='newton-cg')

# %%
from sklearn.model_selection import cross_val_predict
predLR = cross_val_predict(estimator = classifier, X = X_tfidf, y = y, cv = 10)

# %%
from sklearn.metrics import confusion_matrix
conf_mat2 = confusion_matrix(y, predLR)
conf_mat2
# Out:
# array([[859,  20,  87,   4, 131],
#        [116, 368,  66,  16,  83],
#        [127,  13, 677,  32, 168],
#        [ 28,  11,  80, 430,  88],
#        [229,  24, 174,  49, 521]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y, predLR))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.63      0.78      0.70      1101
#         fear       0.84      0.57      0.68       649
#        happy       0.62      0.67      0.64      1017
#         love       0.81      0.68      0.74       637
#      sadness       0.53      0.52      0.52       997
#
#     accuracy                           0.65      4401
#    macro avg       0.69      0.64      0.66      4401
# weighted avg       0.66      0.65      0.65      4401

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=10, leaf_size=1, n_jobs= -1, weights= 'distance')
knn.fit(X_tfidf, y)
# Out:
# KNeighborsClassifier(leaf_size=1, n_jobs=-1, n_neighbors=10, weights='distance')

# %%
predKNN = cross_val_predict(estimator = knn, X = X_tfidf, y = y, cv = 10)

# %%
conf_mat = confusion_matrix(y, predKNN)

# %%
conf_mat
# Out:
# array([[645,  87,  84, 125, 160],
#        [114, 280,  46,  88, 121],
#        [143,  69, 415, 191, 199],
#        [ 23,  16,  38, 496,  64],
#        [202,  93, 130, 225, 347]])

# %%
print(classification_report(y, predKNN))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.57      0.59      0.58      1101
#         fear       0.51      0.43      0.47       649
#        happy       0.58      0.41      0.48      1017
#         love       0.44      0.78      0.56       637
#      sadness       0.39      0.35      0.37       997
#
#     accuracy                           0.50      4401
#    macro avg       0.50      0.51      0.49      4401
# weighted avg       0.51      0.50      0.49      4401

# %%
from sklearn.naive_bayes import MultinomialNB
clf=MultinomialNB()
clf.fit(X_tfidf, y)
# Out:
# MultinomialNB()

# %%
predNB = cross_val_predict(estimator = clf, X = X_tfidf, y = y, cv = 10)
conf_matNB = confusion_matrix(y, predNB)

# %%
print(classification_report(y, predNB))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.53      0.87      0.66      1101
#         fear       0.96      0.15      0.27       649
#        happy       0.66      0.55      0.60      1017
#         love       0.90      0.33      0.48       637
#      sadness       0.43      0.61      0.51       997
#
#     accuracy                           0.55      4401
#    macro avg       0.70      0.50      0.50      4401
# weighted avg       0.66      0.55      0.53      4401

# %%
from sklearn.svm import SVC
svm=SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
svm.fit(X_tfidf, y)
# Out:
# SVC(gamma='auto', kernel='linear')

# %%
svmPred = cross_val_predict(estimator = svm, X = X_tfidf, y = y, cv = 10)

# %%
conf_matSVM = confusion_matrix(y, svmPred)

# %%
print(classification_report(y, svmPred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.64      0.75      0.69      1101
#         fear       0.88      0.57      0.69       649
#        happy       0.62      0.64      0.63      1017
#         love       0.80      0.69      0.74       637
#      sadness       0.50      0.54      0.52       997
#
#     accuracy                           0.64      4401
#    macro avg       0.69      0.64      0.65      4401
# weighted avg       0.66      0.64      0.64      4401
