# %% [markdown]
# # AIM0407D2203 Lab 2A Rule-Based Chatbot
# ---
# Pada tahun 1950, Alan Turing mengajukan pertanyaan, *Bisakah mesin berpikir?*<br>Sejak saat itu, praktisi Kecerdasan Buatan memiliki tantangan untuk membuat mesin dapat berpikir atau dengan kata sederhana menyamarkannya sebagai manusia.
#
# Tugas utama chatbot adalah menghasilkan respons yang sesuai dari input bahasa alami yang diberikan oleh manusia. Ada beberapa cara untuk menghasilkan respons yang mendefinisikan mekanisme pemodelan chatbot seperti yang ditunjukkan pada gambar dibawah ini:
#
#
# 1. **Classical/Rule‑Based Approaches** <br> Pendeketan paling klasik disebut sebagai chatbot berbasis aturan. Chatbot ini juga dikenal sebagai decision-tree bot. Seperti namanya, chatbot ini menggunakan serangkaian aturan yang ditentukan sebelumnya. Aturan ini memetakan daftar pertanyaan yang mungkin diberikan oleh pengguna dan respon yang sesuai. Sehingga, chatbot berbasis aturan akan memberikan respons berdasarkan query yang diekstraksi dari pengguna. <br> Chatbot berbasis aturan dapat menggunakan aturan yang sangat sederhana atau rumit. Namun, chatbot berbasis aturan tidak dapat menjawab pertanyaan apa pun di luar aturan yang telah ditentukan. Sehingga, chatbot ini tidak belajar melalui interaksi.
#
# 2. **Learning-Based Approaches** <br> Pendeketan lebih modern ditunjukkan oleh chatbot berbasis pembelajaran. Chatbot ini menggunakan algoritma pembelajaran tertentu untuk melatih suatu dataset. Terdapat dua cara chatbot berbasis pembelajaran memberikan respon: retrieval-based dan generative. <br>Pendekatan retrieval-based mengambil respon dari kumpulan data berdasarkan input pengguna. Biasanya chatbot ini digunakan untuk merespon satu subjek tertentu (closed domain). Sedangkan generative chatbot termasuk open domain yang akan menghasilkan responnya sendiri dari kombinasi bahasa alami daripada memilih repson yang telah ditentukan sebelumnya.
#
# Pada eksperimen yang pertama, kita akan membuat chatbot paling sederhana menggunakan pendeketan berbasis aturan.
#
# ![image.png](data:image/png;base64,...)

# %%
import nltk
from nltk.chat.util import Chat, reflections

# %%
# definisi aturan
pairs = [
    [
        r"(hi|halo)",
        ["Halo, siapa nama kamu?"],
    ],
    [
        r"namaku (.*)",
        ["Salam kenal %1, bagaimana kabarmu hari ini?"],
    ],
    [
        r"kabarku (.*)",
        ["Senang mendengarnya. Apa yang kamu lakukan hari ini?"]
    ],
    [
        r"(.*) orbit future academy (.*)",
        ["Orbit Future Academy didirikan dengan tujuan untuk meningkatkan kualitas hidup melalui inovasi, pendidikan, dan pelatihan keterampilan"]
    ],
    [
        r"saya (.*)",
        [
            "Semangat ya!", 
            "Tetaplah seperti itu, lanjutkan!"
        ],
    ],
    [
        r"quit",
        ["Sampai jumpa! Senang mengobrol denganmu ..."],
    ]
  ]

# %%
print("Halo, saya adalah Bot dan saya senang mengobrol. Gunakan bahasa Indonesia yang baku tanpa singkatan. Ketik 'quit' untuk mengakhiri obrolan!")

chat = Chat(pairs, reflections)
chat.converse()
# Out:
# Halo, saya adalah Bot dan saya senang mengobrol. Gunakan bahasa Indonesia yang baku tanpa singkatan. Ketik 'quit' untuk mengakhiri obrolan!
# >hi
# Halo, siapa nama kamu?
# >hii
# Halo, siapa nama kamu?
# >saya cahyo
# Semangat ya!
# >namaku cahyo
# Salam kenal cahyo, bagaimana kabarmu hari ini?
# >kabrku baik
# None
# >halo
# Halo, siapa nama kamu?
# >orbit
# None
# >orbit future academy
# None
# >apa itu orbit future academy
# Orbit Future Academy didirikan dengan tujuan untuk meningkatkan kualitas hidup melalui inovasi, pendidikan, dan pelatihan keterampilan
# >quit
# Sampai jumpa! Senang mengobrol denganmu ...
